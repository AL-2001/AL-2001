# %%
 # import libraries
    
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8) # adjusts configuration of plots we will create


#read data

df=pd.read_csv('movies.csv')

# %%
df.head()
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# look for missing data and change Nan to None data type if type =object 
#if type =float64 or int 64,change to 0


for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%' .format(col,pct_missing))
    if df[col].dtype==np.int64:
        df[col]=df[col].replace({np.nan:0})
    elif df[col].dtype==np.float64:
        df[col]=df[col].replace({np.nan:0})
    else:
        df[col]=df[col].replace({np.nan:None})
df
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.0%
# gross - 0.0%
# company - 0.002217005738132499%
# runtime - 0.0%
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life   None      Drama  2020
# ...

# %%
# data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# get rid of .0 in the votes,budget,gross,runtime

df["budget"]=df["budget"].astype('int64')
df["gross"]=df["gross"].astype('int64')
df["votes"]=df["votes"].astype('int64')
df["runtime"]=df["runtime"].astype('int64')

# %%
df.tail()
# Out:
#                name rating   genre  year                          released  \
# 7663   More to Life   None   Drama  2020  October 23, 2020 (United States)
# 7664    Dream Round   None  Comedy  2020  February 7, 2020 (United States)
# 7665  Saving Mbango   None   Drama  2020         April 27, 2020 (Cameroon)
# 7666   It's Just Us   None   Drama  2020   October 1, 2020 (United States)
# 7667      Tee em el   None  Horror  2020   August 19, 2020 (United States)
#
#       score  votes       director         writer              star  \
# 7663    3.1     18  Joseph Ebanks  Joseph Ebanks      Shannon Bond
# 7664    4.7     36   Dusty Dukatz    Lisa Huston  Michael Saquella
# 7665    5.7     29   Nkanya Nkwai   Lynno Lovert      Onyama Laura
# 7666    0.0      0  James Randall  James Randall     Christina Roz
# 7667    5.7      7   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso
#
#             country  budget  gross                    company  runtime
# ...

# %%
# some rows do not have maching years in year and released columns 
#create new column which seperates the string by ',' and add only the 3rd column of that 
#seperation
df['year_correct']=df['released'].str.partition(sep=',')[2]
df['year_correct']=df['year_correct'].str.strip().str[:4]
df.add(df['year_correct'])
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%' .format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.0%
# gross - 0.0%
# company - 0.002217005738132499%
# runtime - 0.0%
# year_correct - 0.0002608242044861763%
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# ...

# %%
df.drop(columns=['year'],inplace=True)
df
# Out:
#                                                 name rating      genre  \
# 0                                        The Shining      R      Drama
# 1                                    The Blue Lagoon      R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                          Airplane!     PG     Comedy
# 4                                         Caddyshack      R     Comedy
# ...                                              ...    ...        ...
# 7663                                    More to Life   None      Drama
# 7664                                     Dream Round   None     Comedy
# 7665                                   Saving Mbango   None      Drama
# 7666                                    It's Just Us   None      Drama
# 7667                                       Tee em el   None     Horror
#
#                               released  score    votes         director  \
# ...

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name rating    genre  \
# 5445                                      Avatar  PG-13   Action
# 7445                           Avengers: Endgame  PG-13   Action
# 3045                                     Titanic  PG-13    Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action
# 7244                      Avengers: Infinity War  PG-13   Action
# ...                                          ...    ...      ...
# 1617                             Mortal Passions      R    Crime
# 1614                              Edge of Sanity      R   Horror
# 1606                                   I, Madman      R  Fantasy
# 1601                        My Twentieth Century   None   Comedy
# 7667                                   Tee em el   None   Horror
#
#                                released  score    votes        director  \
# 5445  December 18, 2009 (United States)    7.8  1100000   James Cameron
# ...

# %%
pd.set_option('display.max_rows',None) #display all rows
df=df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
#see if there are any duplicates and drop them

df.drop_duplicates()
df.head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# ...

# %%
# budget high correlation
#company high correlation

# %%
#scatter plot with budget vs gross_revenue

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('budget vs gross revenue')
plt.xlabel('budget')
plt.ylabel('gross revenue')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# ...

# %%
#plot budget vs gross using seaborn

sns.regplot(x=df['budget'],y=df['gross'],data=df,scatter_kws={'color':'red'},line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# start looking at correlation
df.corr(method='pearson') #pearson,kendall,spearman
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
# high correlation between busdget and gross, i was right

correlation_matrix=df.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
# look at company

# numeralise the object columns

df_numerised = df.copy(deep=True)
for col in df_numerised.columns:
    if(df_numerised[col].dtype)=='object':
        df_numerised[col]=df_numerised[col].astype('category')
        df_numerised[col]=df_numerised[col].cat.codes
        
df_numerised.head()
# Out:
#       name  rating  genre  released  score    votes  director  writer  star  \
# 5445   533       5      0       696    7.8  1100000      1155    1778  2334
# 7445   535       5      0       183    8.4   903000       162     743  2241
# 3045  6896       5      6       704    7.8  1100000      1155    1778  1595
# 6663  5144       5      0       698    7.8   876000      1125    2550   524
# 7244   536       5      0       192    8.4   897000       162     743  2241
#
#       country     budget       gross  company  runtime  year_correct
# 5445       55  237000000  2847246203     2253      162            30
# 7445       55  356000000  2797501328     1606      181            40
# 3045       55  200000000  2201647264     2253      194            18
# 6663       55  245000000  2069521700     1540      138            36
# 7244       55  321000000  2048359754     1606      149            39

# %%
df.head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# ...

# %%
correlation_matrix=df_numerised.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df_numerised.corr()
# Out:
#                   name    rating     genre  released     score     votes  \
# name          1.000000 -0.008069  0.016355 -0.011311  0.016377  0.013038
# rating       -0.008069  1.000000  0.072423  0.016613  0.006192  0.033743
# genre         0.016355  0.072423  1.000000  0.029822  0.027384 -0.145296
# released     -0.011311  0.016613  0.029822  1.000000  0.039814  0.015878
# score         0.016377  0.006192  0.027384  0.039814  1.000000  0.407101
# votes         0.013038  0.033743 -0.145296  0.015878  0.407101  1.000000
# director      0.009079  0.019483 -0.015258 -0.001478  0.010568  0.000349
# writer        0.009081 -0.005921  0.006567 -0.002404  0.022098  0.001127
# star          0.006472  0.013405 -0.005477  0.015777 -0.000026 -0.019146
# country      -0.010737  0.081244 -0.037615 -0.020427 -0.133346  0.073525
# budget        0.020548 -0.081939 -0.334021  0.009145  0.056863  0.486931
# gross         0.006989 -0.095450 -0.234297  0.000519  0.186012  0.632870
# ...

# %%
correlation_matrix2=df_numerised.corr()
corr_pairs=correlation_matrix2.unstack()
print(corr_pairs['company']['budget'])
corr_pairs['gross']['budget']
# Out:
# 0.18647434710991762
# 0.7501571968030822

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# budget        genre          -0.334021
# genre         budget         -0.334021
#               gross          -0.234297
# gross         genre          -0.234297
# genre         votes          -0.145296
# votes         genre          -0.145296
# score         country        -0.133346
# country       score          -0.133346
# gross         rating         -0.095450
# rating        gross          -0.095450
# genre         year_correct   -0.082082
# year_correct  genre          -0.082082
# budget        rating         -0.081939
# rating        budget         -0.081939
# year_correct  country        -0.074085
# country       year_correct   -0.074085
# runtime       country        -0.073319
# country       runtime        -0.073319
# company       genre          -0.071067
# genre         company        -0.071067
# runtime       genre          -0.052914
# genre         runtime        -0.052914
#               country        -0.037615
# country       genre          -0.037615
# ...

# %%
high_corr=sorted_pairs[sorted_pairs>0.5]
high_corr
# Out:
# votes         gross           0.632870
# gross         votes           0.632870
# budget        gross           0.750157
# gross         budget          0.750157
# year_correct  year            0.992072
# year          year_correct    0.992072
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64

# %%
#votes and gross earnings had a high positive correlation
#as well as budget and gross earnings
#company and gross earnings had a low correlation, woring on this aspect
